# %% [markdown]
# # Dependencies

# %%
 # Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Read CSV

# %%
all_file ="../YTSpotify/all_data.csv"

# Read our all_data file 
all_df = pd.read_csv(all_file, encoding="ISO-8859-1")

all_df.head()
# Out:
#    acousticness                                     artists  danceability  \
# 0         0.995                         ['Carl Woitschach']         0.708
# 1         0.994    ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                    ['Seweryn GoszczyÅski']         0.749
# 3         0.995                        ['Francisco Canaro']         0.781
# 4         0.990  ['FrÃ©dÃ©ric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# 1    8    0.0763   -28.454     1
# 2    5    0.1190   -19.924     0
# 3    1    0.1110   -14.734     0
# 4   11    0.0980   -16.829     1
#
#                                             name  popularity release_date  \
# 0                    Singende Bataillone 1. Teil           0         1928
# 1     FantasiestÃ¼cke, Op. 111: PiÃ¹ tosto lento           0         1928
# 2                 Chapter 1.18 - Zamek kaniowski           0         1928
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0   1928-09-25
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1         1928
#
#    speechiness    tempo  valence  year
# 0       0.0506  118.469   0.7790  1928
# 1       0.0462   83.972   0.0767  1928
# 2       0.9290  107.177   0.8800  1928
# 3       0.0926  108.003   0.7200  1928
# 4       0.0424   62.149   0.0693  1928

# %% [markdown]
# # Organize Data Frame

# %%
# Organize the columns so they are in a more logical order
all_df = all_df[[
    "artists", "year","popularity",  "acousticness", "danceability", "duration_ms", "energy", 
    "instrumentalness", "liveness", "loudness", "name", "release_date",
    "speechiness", "tempo", "valence" ]]

# Rename columns for readability
all_df = all_df.rename(columns={"artists": "Artists", "year": "Year", "acousticness": "Acousticness", 
                                "danceability": "Danceability", "duration_ms": "Duration", "energy": "Energy", 
                                "instrumentalness": "Instrumentalness", "liveness": "Liveness", 
                                "loudness": "Loudness", "name": "Song", 
                                "popularity": "Popularity", "release_date": "Release Date",
                                "speechiness": "Speechiness", "tempo": "Tempo", "valence": "Valence"})

#reset index
all_df.reset_index(drop=True, inplace=True)

all_df.head()
# Out:
#                                       Artists  Year  Popularity  Acousticness  \
# 0                         ['Carl Woitschach']  1928           0         0.995
# 1    ['Robert Schumann', 'Vladimir Horowitz']  1928           0         0.994
# 2                    ['Seweryn GoszczyÅski']  1928           0         0.604
# 3                        ['Francisco Canaro']  1928           0         0.995
# 4  ['FrÃ©dÃ©ric Chopin', 'Vladimir Horowitz']  1928           1         0.990
#
#    Danceability  Duration  Energy  Instrumentalness  Liveness  Loudness  \
# 0         0.708    158648  0.1950             0.563    0.1510   -12.428
# 1         0.379    282133  0.0135             0.901    0.0763   -28.454
# 2         0.749    104300  0.2200             0.000    0.1190   -19.924
# 3         0.781    180760  0.1300             0.887    0.1110   -14.734
# 4         0.210    687733  0.2040             0.908    0.0980   -16.829
#
#                                             Song Release Date  Speechiness  \
# 0                    Singende Bataillone 1. Teil         1928       0.0506
# 1     FantasiestÃ¼cke, Op. 111: PiÃ¹ tosto lento         1928       0.0462
# 2                 Chapter 1.18 - Zamek kaniowski         1928       0.9290
# 3  Bebamos Juntos - Instrumental (Remasterizado)   1928-09-25       0.0926
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61         1928       0.0424
#
#      Tempo  Valence
# 0  118.469   0.7790
# 1   83.972   0.0767
# 2  107.177   0.8800
# 3  108.003   0.7200
# 4   62.149   0.0693

# %% [markdown]
# # Sort By Popularity

# %%
#sort by popularity
popularity_df = all_df.sort_values(by='Popularity', ascending=False)

#top 50 songs
top_50 = popularity_df.head(50)
top_50
# Out:
#                                              Artists  Year  Popularity  \
# 87942                                 ['The Weeknd']  2020         100
# 87940                      ['DaBaby', 'Roddy Ricch']  2020          99
# 87949                       ['Powfu', 'beabadoobee']  2020          97
# 87941     ['THE SCOTTS', 'Travis Scott', 'Kid Cudi']  2020          96
# 87852                        ['Surf Mesa', 'Emilee']  2019          95
# 87946                                      ['Drake']  2020          95
# 87840                                ['Roddy Ricch']  2019          95
# 87844                     ['BENEE', 'Gus Dapperton']  2019          95
# 87943                             ['StaySolidRocky']  2020          94
# 87951                                    ['6ix9ine']  2020          94
# 87858                                ['Tones And I']  2019          94
# 87953             ['Ariana Grande', 'Justin Bieber']  2020          94
# 87952                 ['Lady Gaga', 'Ariana Grande']  2020          94
# 87850                                   ['Dua Lipa']  2019          93
# 87845                                   ['Doja Cat']  2019          93
# 87842                                   ['Surfaces']  2019          93
# 87856                              ['Lewis Capaldi']  2019          92
# 87909                     ['KAROL G', 'Nicki Minaj']  2019          92
# 87945                                  ['Lil Mosey']  2020          92
# 87890                               ['Topic', 'A7S']  2019          92
# 87944                                ['Jack Harlow']  2020          92
# 87741                              ['Trevor Daniel']  2018          92
# 87970                                  ['Bad Bunny']  2020          92
# 87843                             ['Arizona Zervas']  2019          92
# 87947            ['Megan Thee Stallion', 'BeyoncÃ©']  2020          92
# 87969                                   ['Doja Cat']  2020          92
# 87540                               ['Travis Scott']  2016          92
# 87977  ['Bad Bunny', 'Jowell & Randy', 'Nengo Flow']  2020          92
# 87742                               ['Travis Scott']  2018          92
# 87971                                 ['The Weeknd']  2020          91
# 87865                                   ['Maroon 5']  2019          91
# 87847                               ['Travis Scott']  2019          91
# 87863                              ['Billie Eilish']  2019          91
# 87440                           ['Melanie Martinez']  2015          91
# 87957                       ['Marshmello', 'Halsey']  2020          91
# 87948                                ['Don Toliver']  2020          90
# 97637                                     ['Regard']  2019          90
# 88036    ['Black Eyed Peas', 'Ozuna', 'J. Rey Soul']  2020          90
# 87949   2020-02-08       0.1350  144.026   0.3480
# 87941   2020-04-24       0.0514  129.979   0.2800
# 87852   2019-11-26       0.0892  112.050   0.3300
# 87946   2020-04-03       0.2010   81.618   0.8370
# 87840   2019-12-06       0.0559  116.971   0.6420
# 87844   2019-11-15       0.0534  128.977   0.8170
# 87943   2020-04-21       0.0622  130.022   0.6290
# 87951   2020-05-08       0.3410  178.462   0.3930
# 87858   2019-10-17       0.0924   98.027   0.5130
# 87953   2020-05-08       0.0418  178.765   0.5370
# 87952   2020-05-22       0.0397  123.056   0.6460
# 87850   2019-10-31       0.0842  123.941   0.6770
# 87845   2019-11-07       0.1580  110.962   0.7860
# 87842   2019-01-06       0.0578  112.022   0.6940
# 87856   2019-05-17       0.0319  109.891   0.4460
# 87909   2019-11-07       0.2980  101.085   0.5740
# 87945   2020-02-07       0.0383   99.034   0.3490
# 87890   2019-12-19       0.2180  122.031   0.6640
# 87944   2020-03-13       0.2450  145.062   0.8260
# 87741   2018-10-05       0.0364  127.087   0.2360
# 87970   2020-02-28       0.0695   97.014   0.4530
# 87843   2019-10-10       0.1480  116.735   0.4570
# 87947   2020-04-29       0.2800   84.459   0.6360
# 87969   2020-01-23       0.2220  125.989   0.5750
# 87540   2016-09-16       0.0484  130.049   0.4300
# 87977   2020-02-28       0.3790   96.172   0.6850
# 87742   2018-08-03       0.2220  155.008   0.4460
# 87971   2020-03-20       0.0346  100.021   0.7170
# 87865   2019-09-20       0.0546   91.019   0.5750
# 87847   2019-10-04       0.0317   76.469   0.0605
# 87863   2019-03-29       0.3750  135.128   0.5620
# 87440   2015-08-14       0.0475  123.970   0.4460
# 87957   2020-05-01       0.0457   93.995   0.4520
# 87948   2020-03-13       0.0376  162.948   0.4530
# 97637   2019-07-26       0.0874  117.948   0.8840
# 88036   2020-04-10       0.0473  105.013   0.4280
# 87954   2020-01-10       0.4810  142.037   0.5080
# 87989   2020-05-28       0.4670   94.634   0.4850
# 87964   2020-02-07       0.0552  148.014   0.8600
# 97738   2020-03-27       0.0886  113.012   0.4670
# 87851   2019-12-13       0.0465   95.390   0.5570
# 87857   2019-11-13       0.0994  120.006   0.2430
# 97742   2020-03-27       0.0842  123.941   0.6770
# 97752   2020-03-12       0.0407  129.856   0.4340
# 87859   2019-10-17       0.1290   75.801   0.6040
# 87959   2020-05-01       0.2040  111.004   0.7450
# 87950   2020-04-24       0.0310  142.942   0.2230
# 87962   2020-03-06       0.3340  168.983   0.6800

# %% [markdown]
# # Top 50 Artists VS Danceability

# %%
#top 50 artists Vs Danceability - alphabetical order
plt.rcParams["figure.figsize"] = [25, 5]
plt.xlim(-1,43)
artists = top_50.groupby('Artists')['Danceability'].mean()
artists.plot(kind='bar', color="green")
plt.title("Top 50 Artists VS Danceability Rating")
plt.xlabel("Artists")
plt.ylabel("Danceability")
plt.savefig("../YTSpotify/Images/practice.png", bbox_inches="tight")
plt.show()
# Out:
# /Users/Jillian_Gonder/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/Jillian_Gonder/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 141 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # Top 50 Artists VS Danceability

# %%
#top 50 artists Vs Danceability - alphabetical order
songs = top_50.groupby('Song')['Danceability'].mean()
songs.plot(kind='bar', color="purple")
plt.title("Top 50 Songs VS Danceability Rating")
plt.xlabel("Song")
plt.ylabel("Danceability")
plt.savefig("../YTSpotify/Images/top_artists.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Top 1000 Energy of a Song VS Popularity

# %%
#Energy (happiness) of Song Vs Popularity colors = duration = top 1000
top_1000 = popularity_df.head(1000)
valence = top_1000.plot.scatter(x='Energy',
                      y='Danceability',
                       c='Popularity',
                      colormap="rainbow", sharex=False)

plt.title("Top 1000 - Energy (Loudness) Relationship to Popularity and Danceability")
plt.savefig("../YTSpotify/Images/Energy_scatter.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Top 1000 Valence (Happiness) of a Song VS Popularity

# %%
#Valence (happiness) of Song Vs Popularity colors = duration = top 1000
top_1000 = popularity_df.head(1000)
valence = top_1000.plot.scatter(x='Valence',
                      y='Danceability',
                       c='Popularity',
                      colormap='viridis', sharex=False)

plt.title("Top 1000 - Valence (Happiness) Relationship to Popularity and Danceability")
plt.savefig("../YTSpotify/Images/Valence_scatter.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Top 1000 Tempo of Song VS Popularity

# %%
#tempo relationship to popularity and duration
top_1000 = popularity_df.head(1000)
tempo = top_1000.plot.scatter(x='Tempo',
                      y='Duration',
                       c='Popularity',
                      colormap='plasma', sharex=False)

plt.title("Tempo (BPM) Relationship to Popularity and Song Duration")
plt.savefig("../YTSpotify/Images/Tempo_scatter.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Chart Release Month VS Popularity

# %%
#top 5000 songs
top_5000 = popularity_df.head(5000)


# Organize the columns so they are in a more logical order
release_df = top_5000[["Year","Release Date", "Popularity","Artists", "Song" ]]


#reset index
release_df.reset_index(drop=True, inplace=True)

# extract month
release_df['Month'] = pd.DatetimeIndex(release_df['Release Date']).month

release_df.head()
# Out:
# <ipython-input-18-cd7869e80c80>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   release_df['Month'] = pd.DatetimeIndex(release_df['Release Date']).month
#    Year Release Date  Popularity                                     Artists  \
# 0  2020   2020-03-20         100                              ['The Weeknd']
# 1  2020   2020-04-17          99                   ['DaBaby', 'Roddy Ricch']
# 2  2020   2020-02-08          97                    ['Powfu', 'beabadoobee']
# 3  2020   2020-04-24          96  ['THE SCOTTS', 'Travis Scott', 'Kid Cudi']
# 4  2019   2019-11-26          95                     ['Surf Mesa', 'Emilee']
#
#                                                 Song  Month
# 0                                    Blinding Lights      3
# 1                       ROCKSTAR (feat. Roddy Ricch)      4
# 2  death bed (coffee for your head) (feat. beabad...      2
# 3                                         THE SCOTTS      4
# 4               ily (i love you baby) (feat. Emilee)     11

# %%
#line graph of month release vs popularity in top 5000
x = release_df.groupby('Month')['Popularity'].mean()
x.plot(kind='line', color="red")
plt.xticks(release_df["Month"])
plt.title("Top 5000 Songs Release Month VS Popularity (1957-2020)")
plt.xlabel("Month")
plt.ylabel("Popularity")
plt.savefig("../YTSpotify/Images/Release_line.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
